# %% [markdown]
# Khofiyya Mulia Rahmi

# %% [markdown]
# # Introduction

# %% [markdown]
# Deskripsi Data Manajemen Klaim BNP Paribas Cardif, diberikan kumpulan data anonim yang berisi variabel kategoris dan numerik yang tersedia saat klaim diterima oleh BNP Paribas Cardif. Semua variabel tipe string adalah kategorikal. Tidak ada variabel ordinal. Kolom "target" Ada variabel target "target", mengklasifikasikan data menjadi dua kelas 1 dan 0. Menghasilkan model yang melakukan tugas klasifikasi.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
plt.style.use('seaborn')

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#    ID  target        v1        v2 v3        v4         v5        v6        v7  \
# 0   3       1  1.335739  8.727474  C  3.921026   7.915266  2.599278  3.176895
# 1   4       1       NaN       NaN  C       NaN   9.191265       NaN       NaN
# 2   5       1  0.943877  5.310079  C  4.410969   5.326159  3.979592  3.928571
# 3   6       1  0.797415  8.304757  C  4.225930  11.627438  2.097700  1.987549
# 4   8       1       NaN       NaN  C       NaN        NaN       NaN       NaN
#
#          v8  ...      v122      v123      v124  v125      v126      v127  \
# 0  0.012941  ...  8.000000  1.989780  0.035754    AU  1.804126  3.113719
# 1  2.301630  ...       NaN       NaN  0.598896    AF       NaN       NaN
# 2  0.019645  ...  9.333333  2.477596  0.013452    AE  1.773709  3.922193
# 3  0.171947  ...  7.018256  1.812795  0.002267    CJ  1.415230  2.954381
# 4       NaN  ...       NaN       NaN       NaN     Z       NaN       NaN
#
#        v128  v129      v130      v131
# ...

# %%
test = pd.read_csv('test.csv')
test.shape
# Out:
# (114393, 132)

# %%
train.describe()
# Out:
#                   ID         target            v1            v2            v4  \
# count  114321.000000  114321.000000  6.448900e+04  6.452500e+04  6.452500e+04
# mean   114228.928228       0.761199  1.630686e+00  7.464411e+00  4.145098e+00
# std     65934.487362       0.426353  1.082813e+00  2.961676e+00  1.148263e+00
# min         3.000000       0.000000 -9.996497e-07 -9.817614e-07 -6.475929e-07
# 25%     57280.000000       1.000000  9.135798e-01  5.316428e+00  3.487398e+00
# 50%    114189.000000       1.000000  1.469550e+00  7.023803e+00  4.205991e+00
# 75%    171206.000000       1.000000  2.136128e+00  9.465497e+00  4.833250e+00
# max    228713.000000       1.000000  2.000000e+01  2.000000e+01  2.000000e+01
#
#                  v5            v6            v7            v8            v9  \
# count  6.569700e+04  6.448900e+04  6.448900e+04  6.570200e+04  6.447000e+04
# mean   8.742359e+00  2.436402e+00  2.483921e+00  1.496569e+00  9.031859e+00
# ...

# %% [markdown]
# # Missing Value

# %%
missing = train.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar(figsize=(15,6))
plt.show()

# %%
train_val = train.copy()
test_val = test.copy()

# fill NaN values with -99
for f in train_val.columns:
    if train_val[f].dtype == 'float64':
        train_val[f].fillna(-99, inplace=True)
        test_val[f].fillna(-99, inplace=True)
        #train_val.loc[:,f][np.isnan(train_val[f])] = -99
        #test_val[f][np.isnan(test_val[f])] = -99
        
    elif train_val[f].dtype == 'object':
        train_val[f][train_val[f] != train[f]] = -99
        test_val[f][test_val[f] != test[f]] = -99
# Out:
# <ipython-input-30-3e29a4bb52ef>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_val[f][train_val[f] != train[f]] = -99
# <ipython-input-30-3e29a4bb52ef>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_val[f][test_val[f] != test[f]] = -99

# %%
train_val.head()
# Out:
#    ID  target         v1         v2 v3         v4         v5         v6  \
# 0   3       1   1.335739   8.727474  C   3.921026   7.915266   2.599278
# 1   4       1 -99.000000 -99.000000  C -99.000000   9.191265 -99.000000
# 2   5       1   0.943877   5.310079  C   4.410969   5.326159   3.979592
# 3   6       1   0.797415   8.304757  C   4.225930  11.627438   2.097700
# 4   8       1 -99.000000 -99.000000  C -99.000000 -99.000000 -99.000000
#
#           v7         v8  ...       v122       v123       v124  v125  \
# 0   3.176895   0.012941  ...   8.000000   1.989780   0.035754    AU
# 1 -99.000000   2.301630  ... -99.000000 -99.000000   0.598896    AF
# 2   3.928571   0.019645  ...   9.333333   2.477596   0.013452    AE
# 3   1.987549   0.171947  ...   7.018256   1.812795   0.002267    CJ
# 4 -99.000000 -99.000000  ... -99.000000 -99.000000 -99.000000     Z
#
#         v126       v127       v128  v129       v130       v131
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn import preprocessing

for f in train_val.columns:
    if train_val[f].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(np.unique(list(train_val[f].values)  + list(test_val[f].values)))
        train_val[f]   = lbl.transform(list(train_val[f].values))
        test_val[f]  = lbl.transform(list(test_val[f].values))

#train_val.head()

# %% [markdown]
# # Modeling

# %%
train_X = train_val.drop('target', axis=1)
train_y = train_val.target

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=100, random_state=1, oob_score=True)
rfc = rfc.fit(train_X, train_y)
print("%.4f" % rfc.oob_score_)
# Out:
# 0.7775

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Nilai akurasi dari hasil klasifikasi pada data uji didapatkan sebesar 77%, artinya ketepatan model dalam memprediksi  sebesar 77% yang dapat diinterpretasikan bahwa model klasifikasi dengan metode RandomForest.

# %% [markdown]
# # Thankyou
